# %% [markdown]
# # クラスとselfと\_\_init\_\_
#
#
# ## はじめに
# \_\_init\_\_が難しい理由が2つあります。
# - 難しい概念が色々隠れている。
# - 自動的に色々やってくれる。
#
# 目次
# 1. オブジェクトって何？
# 2. クラスって何？
# 3. インスタンス化って何？
# 4. \_\_init\_\_って何？
# 5. selfって何？
#
# ## Step 1. オブジェクトって何？
# 「値」と「処理」をまとめたもの
